# %%
# import dependencies
import os
import numpy as np
import pandas as pd

from scipy.io.arff import loadarff
from os import listdir

# %% [markdown]
# ### Type fold name (fold1/fold2/fold3/fold4)

# %%
selected_fold = 'fold4'

# %%
with open('./cv/'+selected_fold+'_file_names.txt') as f:
    lines = f.readlines()

# %%
class2num = {"class":     {"bus": 0, "cafe/restaurant": 1, "car": 2, "city_center": 3, "forest_path": 4, 
                              "grocery_store": 5, "home": 6, "beach": 7, "library": 8, "metro_station": 9, 
                              "office": 10, "residential_area": 11, "train": 12, "tram": 13, "park": 14}}

# %%
fold1 = np.empty(shape=[0,60])
fold1_class = np.empty(shape=[0,1])

cnt=0
for line in lines:
    line = line.replace("\n","")
    file_name = './DCASE2017_development_set/mfcc_weka/' + line + '.arff'
    print("import file:\t" + line)
    
    # load weka files
    data_arff = loadarff(open(file_name, 'r'))
    data_arff_np = np.array(data_arff[0])
    
    df = pd.DataFrame(data_arff_np)
    
    ## decoding class to string
    df['class'] = df['class'].str.decode("utf-8")
    
    ## convert string to numerical value
    df.replace(class2num, inplace=True)
    
    ## split attributes and classes
    df_attribute = df.drop('class', axis=1).values
    df_class = df['class'].values
    
    ## reshape the array
    #df_attribute = df_attribute.reshape(1,501*60)
    
    fold1 = np.append(fold1, df_attribute, axis=0)
    fold1_class = np.append(fold1_class, df_class)
    cnt+=1
    
print("In total\t" + str(cnt) + "\tfiles")
# Out:
# import file:	a016_120_130
# import file:	a016_130_140
# import file:	a016_140_150
# import file:	a016_20_30
# import file:	a016_10_20
# import file:	a016_0_10
# import file:	a016_190_200
# import file:	a016_180_190
# import file:	a016_200_210
# import file:	a016_170_180
# import file:	a016_160_170
# import file:	a016_150_160
# import file:	a016_90_100
# import file:	a016_110_120
# import file:	a016_100_110
# import file:	a016_70_80
# import file:	a016_80_90
# import file:	a016_60_70
# import file:	a016_30_40
# import file:	a016_40_50
# import file:	a016_50_60
# import file:	a014_120_130
# import file:	a014_130_140
# import file:	a014_140_150
# import file:	a014_70_80
# import file:	a014_60_70
# import file:	a014_80_90
# import file:	a014_180_190
# import file:	a014_190_200
# import file:	a014_200_210
# import file:	a014_150_160
# import file:	a014_170_180
# import file:	a014_160_170
# import file:	a014_40_50
# import file:	a014_30_40
# import file:	a014_50_60
# ...

# %%
pd.DataFrame(fold1)
# Out:
#                 0           1          2          3          4          5   \
# 0      -531.658293  114.653858   3.714690  30.034693  -7.286200  21.847900
# 1      -544.487027  114.499931  -6.366338  36.733097   2.031951  41.452181
# 2      -545.580273  106.405269 -18.572355  36.988217   5.505343  41.621998
# 3      -544.730886  110.306082 -15.842527  39.204415   3.872692  40.578383
# 4      -552.284985  115.676632  -9.136771  37.976840   2.293914  44.727765
# 5      -549.071833  108.794696 -13.677542  27.684200  -2.036758  39.828724
# 6      -536.946689  116.641207 -17.213948  23.774360   3.502561  41.854748
# 7      -551.497147  108.533483 -10.751296  34.539677   5.481762  44.124600
# 8      -534.223059  127.825445  -8.858070  26.226918  -1.425101  32.330241
# 9      -534.515398  125.763311  -2.220035  29.260158  -1.134319  40.525182
# 10     -535.771560  125.998179 -10.201682  27.538365  -8.289431  39.498900
# ...

# %%
len(fold1_class)
# Out:
# 586170

# %%
np.save('./cv/'+selected_fold+'_unshape.npy', fold1)

# %%
np.save('./cv/'+selected_fold+'_class_unshape.npy', fold1_class)

# %%
# Check if data is well-formed
data_1 = np.load('./cv/fold1_unshape.npy')
pd.DataFrame(data_1)
# Out:
#                 0           1          2          3          4          5   \
# 0      -642.367014   71.810496  21.448299  59.678364  23.445048  38.206664
# 1      -619.557079   93.906776  33.897002  76.390571  11.614350  41.456723
# 2      -621.368127   87.682528  26.424733  83.221678  12.797362  36.300492
# 3      -626.236337   94.801458  29.823774  76.632642  17.553262  42.442076
# 4      -628.095299   84.291032  16.779598  65.769710  -1.824692  32.849695
# 5      -618.486605  102.574247  23.590477  76.815209  12.459744  33.427683
# 6      -634.926999   85.013483  20.176944  67.571555  12.038689  39.947562
# 7      -622.836588   87.264522  20.738515  86.422384  18.120276  43.184024
# 8      -621.420439   96.146605  32.205725  75.581953  13.287745  42.054745
# 9      -624.787625   93.368278  22.951415  68.139571   5.429124  35.611166
# 10     -632.808738   83.316735   9.377495  66.495380   8.116917  42.385485
# ...

# %%
# Check if data is well-formed
data_1_class = np.load('./cv/fold1_class_unshape.npy')
pd.DataFrame(data_1_class)
# Out:
#            0
# 0        7.0
# 1        7.0
# 2        7.0
# 3        7.0
# 4        7.0
# 5        7.0
# 6        7.0
# 7        7.0
# 8        7.0
# 9        7.0
# 10       7.0
# 11       7.0
# 12       7.0
# 13       7.0
# 14       7.0
# 15       7.0
# 16       7.0
# 17       7.0
# 18       7.0
# 19       7.0
# 20       7.0
# 21       7.0
# 22       7.0
# 23       7.0
# 24       7.0
# 25       7.0
# 26       7.0
# 27       7.0
# 28       7.0
# 29       7.0
# ...      ...
# 586140  13.0
# 586141  13.0
# 586142  13.0
# 586143  13.0
# 586144  13.0
# 586145  13.0
# 586146  13.0
# 586147  13.0
# 586148  13.0
# 586149  13.0
# 586150  13.0
# 586151  13.0
# 586152  13.0
# 586153  13.0
# 586154  13.0
# 586155  13.0
# 586156  13.0
# 586157  13.0
# 586158  13.0
# 586159  13.0
# 586160  13.0
# 586161  13.0
# 586162  13.0
# 586163  13.0
# 586164  13.0
# 586165  13.0
# 586166  13.0
# 586167  13.0
# 586168  13.0
# 586169  13.0
#
# [586170 rows x 1 columns]

# %%
# Check if data is well-formed
data_2 = np.load('./cv/fold2_unshape.npy')
